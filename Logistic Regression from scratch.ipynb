# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('C:\Python\Datasets\data.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df['diagnosis'][3]
# Out:
# 'M'

# %%
from sklearn import datasets
bc = datasets.load_breast_cancer()
X, y= bc.data, bc.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (455, 30)
# (114, 30)
# (455,)
# (114,)

# %%
print(type(X_train))
print(type(y_train))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
class LogisticRegression:
    
    def __init__(self, lr=0.001, n_it=1000):
        self.lr=lr
        self.n_it = n_it
        self.weights = None
        self.bias = None
        
    def fit(self, X , y): #X -> mxn Y-> 1xm
        #Initialize:
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0
        
        #Gradient Descent Application:
        for i in range(self.n_it):
            y_lin = np.dot(X, self.weights + self.bias)
            y_pred = self._sigmoid(y_lin)
            
            #Derivatives Calculations:
            dw = 2*(1/n_samples)*np.dot(X.T, y_pred-y)
            db = 2*(1/n_samples)*np.sum(y_pred-y)
            
            #Refining the weights:
            self.weights -= self.lr*dw
            self.bias -= self.lr*db
                    
    def predict(self, X):
        y_lin = np.dot(X, self.weights + self.bias)
        y_pred = self._sigmoid(y_lin)
        y_pred_cls = [1 if i>0.5 else 0 for i in y_pred]
        return y_pred_cls
        
        
    def _sigmoid(self, x):
        return 1/(1+np.exp(-x))

# %%
regressor = LogisticRegression(lr=0.001, n_it=1000)
regressor.fit(X_train, y_train)
predictions = regressor.predict(X_test)
# Out:
# C:\Users\hritv\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: overflow encountered in exp

# %%
accuracy_score(y_test, predictions)
# Out:
# 0.9035087719298246

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[41,  4],
#        [ 7, 62]], dtype=int64)

# %%
f1_score(y_test, predictions)
# Out:
# 0.9185185185185185

# %%
import seaborn as sns
dff = df[['radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concave points_mean','symmetry_mean','concavity_mean','fractal_dimension_mean','diagnosis']]
dff.head()
list = []
for i in range(dff['diagnosis'].count()):
    if dff['diagnosis'][i]=='M':
        list.append(1)
    else:
        list.append(0)
onj = pd.Series(list)
dff['new_d'] = onj
work = dff[['radius_mean','texture_mean','perimeter_mean','area_mean','smoothness_mean','compactness_mean','concave points_mean','symmetry_mean','concavity_mean','fractal_dimension_mean','new_d']]
work.head(20)
#dff.head()    
sns.pairplot(work)
# Out:
# C:\Users\hritv\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
X = work.iloc[:, 0:10]
y = work.iloc[:, 10]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1234)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)
# Out:
# (455, 10)
# (114, 10)
# (455,)
# (114,)

# %%
class LogisticRegression:
    
    def __init__(self, lr=0.001, n_it=10000):
        self.lr=lr
        self.n_it = n_it
        self.weights = None
        self.bias = None
        
    def fit(self, X , y): #X -> mxn Y-> 1xm
        #Initialize:
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0
        
        #Gradient Descent Application:
        for i in range(self.n_it):
            y_lin = np.dot(X, self.weights + self.bias)
            y_pred = self._sigmoid(y_lin)
            
            #Derivatives Calculations:
            dw = 2*(1/n_samples)*np.dot(X.T, y_pred-y)
            db = 2*(1/n_samples)*np.sum(y_pred-y)
            
            #Refining the weights:
            self.weights -= self.lr*dw
            self.bias -= self.lr*db
                    
    def predict(self, X):
        y_lin = np.dot(X, self.weights + self.bias)
        y_pred = self._sigmoid(y_lin)
        y_pred_cls = [1 if i>0.5 else 0 for i in y_pred]
        return y_pred_cls
        
        
    def _sigmoid(self, x):
        return 1/(1+np.exp(-x))

# %%
regressor = LogisticRegression(lr=0.01, n_it=1000)
regressor.fit(X_train, y_train)
predictions = regressor.predict(X_test)
# Out:
# C:\Users\hritv\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: overflow encountered in exp

# %%
accuracy_score(y_test, predictions)
# Out:
# 0.8333333333333334

# %%
confusion_matrix(y_test, predictions)
# Out:
# array([[52, 17],
#        [ 2, 43]], dtype=int64)

# %%
f1_score(y_test, predictions)
# Out:
# 0.8190476190476191
